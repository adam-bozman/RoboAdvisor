# %% [markdown]
# <a href="https://colab.research.google.com/github/adam-bozman/RoboAdvisor/blob/main/M%26ARoboAdvisorAnalysis_071024_Insample_4turbo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT4-Turbo's Predictive Capacity | Value Enhancing

# %% [markdown]
# ## 4-turbo Insample Setup

# %%
# Load Google Drive
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Import libraries
import pandas as pd
import re
from scipy import stats

# %%
# Load the Excel file
file_path = "/content/drive/My Drive/RoboAdvisor/07_2024/results/4turbo/ValueEnhancing4turboResults.xlsx"
# sheet_name = 'outsampleresults'
df = pd.read_excel(file_path)

# %%
df.tail()
# Out:
#                            Source.Name      dealno    anndate  \
# 1142  ValueEnhancing4turbosample2.xlsx  4176297020 2023-12-27
# 1143  ValueEnhancing4turbosample2.xlsx  4177450020 2023-12-28
# 1144  ValueEnhancing4turbosample2.xlsx  4178034020 2023-12-28
# 1145  ValueEnhancing4turbosample2.xlsx  4177687020 2023-12-28
# 1146  ValueEnhancing4turbosample2.xlsx  4204423020 2023-12-31
#
#                               Target                    Acquirer    effdate  \
# 1142  Hartree Partners LP-Natural Ga            Williams Cos Inc 2024-01-03
# 1143      Marriott-SpringHill Suites  Apple Hospitality REIT Inc 2023-12-28
# 1144  Advanced Micro Instruments Inc                   Enpro Inc 2024-01-30
# 1145                   Key Knife Inc                  Kadant Inc 2024-01-02
# 1146  Undisclosed Care Facilities(4)  Sabra Health Care REIT Inc 2023-12-31
#
#      withdate            form  pct_cash  pct_other  ...  Acquirer List  \
# 1142      NaT  Acq. of Assets       NaN        NaN  ...            NaN
# 1143      NaT  Acq. of Assets       NaN      100.0  ...            NaN
# 1144      NaT  Acq. of Assets       NaN      100.0  ...            NaN
# 1145      NaT          Merger       NaN      100.0  ...            NaN
# 1146      NaT  Acq. of Assets       NaN      100.0  ...            NaN
#
#       aCAR_MM_Window1_1_1  aCAR_MM_Window2_2_2  aCAR_RAW_Window1_1_1  \
# 1142            -0.012332            -0.009283             -0.005986
# 1143            -0.012796            -0.013811             -0.014825
# 1144            -0.013973             0.002472             -0.013344
# 1145            -0.012780            -0.003532             -0.013599
# 1146                  NaN                  NaN                   NaN
#
#      aCAR_RAW_Window2_2_2 tCAR_MM_Window1_1_20 tCAR_MM_Window2_1_63  \
# 1142            -0.003988             0.102395             0.136934
# 1143            -0.010688             0.022850            -0.013773
# 1144             0.009643                  NaN                  NaN
# 1145             0.002164                  NaN                  NaN
# 1146                  NaN                  NaN                  NaN
#
#      tCAR_RAW_Window1_1_20 tCAR_RAW_Window2_1_63  \
# 1142              0.172974              0.249371
# 1143              0.099531              0.160341
# 1144                   NaN                   NaN
# 1145                   NaN                   NaN
# 1146                   NaN                   NaN
#
#                                       Prompt_1_Response
# 1142  Increase\n\n1. **Strategic Synergies**: The ac...
# 1143  Increase\n\n1. **Brand Enhancement**: Acquirin...
# 1144  Increase\n\n1. **Synergy Realization**: If Enp...
# 1145  Increase\n\n1. **Complementary Business Models...
# 1146  Increase\n\n1. **Expansion of Portfolio**: The...
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Functions to Parse Answers

# %%
# Function to process each response
def process_response(response):
    # Initialize result dictionary
    result = {'Primary_Response': 'Invalid Response', 'Reasons': ''}

    # Strip leading/trailing whitespace and split response into lines
    lines = response.strip().split('\n')

    # Extract primary response
    if lines:
        primary_response = lines[0].strip().lower().replace('*', '')  # Remove asterisks and strip whitespace
        primary_response = primary_response.strip("'\"")  # Remove leading/trailing quotation marks
        if primary_response in ['increase', 'decrease', 'no change']:
            result['Primary_Response'] = primary_response.capitalize()

    # Extract reasons only if the primary response is valid
    if result['Primary_Response'] != 'Invalid Response':
        reasons = []
        for line in lines[1:]:
            cleaned_line = line.strip().replace('*', '')  # Remove asterisks and strip whitespace
            match = re.match(r'^\d+\.\s([^:]+):', cleaned_line)
            if match:
                reasons.append(match.group(1).strip())
        if reasons:
            result['Reasons'] = '; '.join(reasons)

    return result

# %%
# Apply the function to the Prompt_1_Response column
df[['Primary_Response', 'Reasons']] = df['Prompt_1_Response'].apply(lambda x: pd.Series(process_response(x)))

# %%
df.head()
# Out:
#                         Source.Name      dealno    anndate  \
# 0  ValueEnhancing4turbosample1.xlsx  3810227020 2021-10-01
# 1  ValueEnhancing4turbosample1.xlsx  3813311020 2021-10-01
# 2  ValueEnhancing4turbosample1.xlsx  3854117020 2021-10-01
# 3  ValueEnhancing4turbosample1.xlsx  3809428020 2021-10-03
# 4  ValueEnhancing4turbosample1.xlsx  3809885020 2021-10-04
#
#                           Target                   Acquirer    effdate  \
# 0      Undisclosed Healthcare Co           i3 Verticals Inc 2021-10-01
# 1  Infinity Infusion Nursing LLC     Option Care Health Inc 2021-10-01
# 2         Luby's Inc-Re Ppty(26)         Store Capital Corp 2021-10-01
# 3                 DentaQuest LLC     Sun Life Financial Inc 2022-06-01
# 4  Elmira Savings Bank.Elmira,NY  Community Bank System Inc 2022-05-16
#
#   withdate            form  pct_cash  pct_other  ...  aCAR_MM_Window2_2_2  \
# 0      NaT  Acq. of Assets       NaN      100.0  ...             0.032039
# 1      NaT  Acq. of Assets       NaN      100.0  ...             0.036801
# 2      NaT  Acq. of Assets       NaN      100.0  ...             0.002719
# 3      NaT          Merger       NaN        NaN  ...                  NaN
# 4      NaT          Merger     100.0        NaN  ...             0.015700
#
#    aCAR_RAW_Window1_1_1  aCAR_RAW_Window2_2_2  tCAR_MM_Window1_1_20  \
# 0             -0.078940              0.022089                   NaN
# 1              0.020590              0.038199                   NaN
# 2              0.008299              0.002682             -0.074415
# 3                   NaN                   NaN                   NaN
# 4              0.033977              0.018452              0.623178
#
#   tCAR_MM_Window2_1_63 tCAR_RAW_Window1_1_20 tCAR_RAW_Window2_1_63  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2            -0.285483              0.138843              0.202044
# 3                  NaN                   NaN                   NaN
# 4             0.545816              0.652974              0.638742
#
#                                    Prompt_1_Response Primary_Response  \
# 0  Increase\n\n1. **Expansion into Healthcare Sec...         Increase
# 1  Increase\n\n1. **Complementary Services**: Opt...         Increase
# 2  Decrease\n\n1. **Divergence in Core Business M...         Decrease
# 3  Increase\n\n1. **Expansion into New Markets**:...         Increase
# 4  Increase\n\n1. **Market Perception and Strateg...         Increase
#
#                                              Reasons
# 0  Expansion into Healthcare Sector; Synergies; M...
# 1  Complementary Services; Market Perception; Fin...
# 2  Divergence in Core Business Models; Integratio...
# 3  Expansion into New Markets; Synergies; Market ...
# 4  Market Perception and Strategic Fit; Financial...
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Save the Output

# %%
# Set path variables
path_to_google_drive = '/content/drive/My Drive/RoboAdvisor/07_2024/results/Cleaned/'
filename = 'ValueEnhancingResponses_Cleaned_Insample_4turbo.xlsx'

# Define global path
path = path_to_google_drive + filename

# Save the cleaned and updated dataframe to a new Excel file
df.to_excel(path, index=False)

# %% [markdown]
# ## Statistical Significance & Accuracy of Responses

# %%
# Filter out rows with empty CAR values
car_columns = ['aCAR_MM_Window1_1_1', 'aCAR_MM_Window2_2_2', 'aCAR_RAW_Window1_1_1', 'aCAR_RAW_Window2_2_2']
df = df.dropna(subset=car_columns)

# %%
# Calculate average returns for each response category
response_groups = df.groupby('Primary_Response')[car_columns].mean()

# %%
# Calculate statistical significance
response_results = {}
for response in df['Primary_Response'].unique():
    if response != 'Invalid Response':
        subset = df[df['Primary_Response'] == response]
        stats_results = {}
        for col in car_columns:
            stats_results[col] = {
                'mean': subset[col].mean(),
                'std': subset[col].std(),
                'count': subset[col].count(),
                't-stat': stats.ttest_1samp(subset[col].dropna(), 0).statistic,
                'p-value': stats.ttest_1samp(subset[col].dropna(), 0).pvalue
            }
        response_results[response] = stats_results

# Print the results
for response, results in response_results.items():
    print(f"Results for {response}:")
    for col, stats in results.items():
        print(f"  {col}: mean={stats['mean']}, std={stats['std']}, count={stats['count']}, t-stat={stats['t-stat']}, p-value={stats['p-value']}")
# Out:
# Results for Increase:
#   aCAR_MM_Window1_1_1: mean=0.003378922399579523, std=0.09033931198267048, count=971, t-stat=1.165496715963748, p-value=0.24410450184415142
#   aCAR_MM_Window2_2_2: mean=-0.0008049721907102924, std=0.09925286622254388, count=971, t-stat=-0.2527245517317059, p-value=0.8005346187578071
#   aCAR_RAW_Window1_1_1: mean=0.006344189702067958, std=0.09348895635003845, count=971, t-stat=2.114586542507163, p-value=0.034719778630845674
#   aCAR_RAW_Window2_2_2: mean=0.004653607201007977, std=0.10337486205979662, count=971, t-stat=1.4027632988905079, p-value=0.1610074135792449
# Results for Decrease:
#   aCAR_MM_Window1_1_1: mean=-0.008101973438210891, std=0.11515650841832256, count=141, t-stat=-0.8354334940056554, p-value=0.40489716250420027
#   aCAR_MM_Window2_2_2: mean=-0.016527929317502254, std=0.11036537815737951, count=141, t-stat=-1.778259541017866, p-value=0.07753182690734883
#   aCAR_RAW_Window1_1_1: mean=-0.011606481757596598, std=0.119175561843976, count=141, t-stat=-1.1564395643219156, p-value=0.24947094374485532
#   aCAR_RAW_Window2_2_2: mean=-0.01891513252917536, std=0.11739244260858271, count=141, t-stat=-1.9132812068829534, p-value=0.05775350823748055
# Results for No change:
#   aCAR_MM_Window1_1_1: mean=0.36897855126350737, std=0.49786095858999496, count=2, t-stat=1.0481128564478581, p-value=0.4850477168488227
#   aCAR_MM_Window2_2_2: mean=0.22632244750802336, std=0.4422883330238502, count=2, t-stat=0.7236642950698408, p-value=0.6012009243571715
#   aCAR_RAW_Window1_1_1: mean=0.35069206098574435, std=0.4738501429106952, count=2, t-stat=1.0466462367535527, p-value=0.48549296121704427
#   aCAR_RAW_Window2_2_2: mean=0.20762777178483705, std=0.41895988009914586, count=2, t-stat=0.7008547231633148, p-value=0.6108347318144687

# %% [markdown]
# ## Functions to Aggregate Common Reasons/Terms

# %%
# Load libraries
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
# Function to calculate reason frequencies
def calculate_reason_frequencies(reasons):
    all_reasons = '; '.join(reasons).split('; ')
    reason_freq = Counter(all_reasons)
    return reason_freq

# Function to plot word cloud
def plot_wordcloud(freq_dict, title):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_dict)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(title, fontsize=15)
    plt.axis('off')
    plt.show()

# %%
# Separate data into value-enhancing and non-value-enhancing deals
value_enhancing = df[df['Primary_Response'] == 'Increase']
non_value_enhancing = df[df['Primary_Response'].isin(['Decrease', 'No change'])]

# %%
# Calculate reason frequencies for each group
full_sample_reason_freq = calculate_reason_frequencies(df['Reasons'])
value_enhancing_reason_freq = calculate_reason_frequencies(value_enhancing['Reasons'])
non_value_enhancing_reason_freq = calculate_reason_frequencies(non_value_enhancing['Reasons'])

# %%
# Plot word clouds for each group
plot_wordcloud(full_sample_reason_freq, 'Reason Frequencies - Full Sample')
plot_wordcloud(value_enhancing_reason_freq, 'Reason Frequencies - Value Enhancing Deals')
plot_wordcloud(non_value_enhancing_reason_freq, 'Reason Frequencies - Non-Value Enhancing Deals')

# %%
# Optionally, print the most common reasons for each group
print("Most common reasons - Full Sample:", full_sample_reason_freq.most_common(20))
print("Most common reasons - Value Enhancing Deals:", value_enhancing_reason_freq.most_common(20))
print("Most common reasons - Non-Value Enhancing Deals:", non_value_enhancing_reason_freq.most_common(20))
# Out:
# Most common reasons - Full Sample: [('Synergies', 229), ('Market Perception', 197), ('Strategic Fit', 183), ('Synergy Realization', 182), ('Expansion into New Markets', 130), ('Market Expansion', 122), ('Complementary Business Models', 117), ('Integration Risks', 98), ('Synergies and Cost Savings', 88), ('Dilution of Shares', 75), ('Expansion of Market Reach', 75), ('Financial Health and Deal Structure', 75), ('Investor Confidence', 73), ('Strategic Expansion', 70), ('Financial Strain', 69), ('Investor Perception', 67), ('Financial Health Perception', 64), ('Investor Sentiment', 57), ('Complementary Product Offerings', 57), ('Financial Synergies', 56)]
# Most common reasons - Value Enhancing Deals: [('Synergies', 229), ('Market Perception', 197), ('Strategic Fit', 183), ('Synergy Realization', 182), ('Expansion into New Markets', 130), ('Market Expansion', 122), ('Complementary Business Models', 117), ('Synergies and Cost Savings', 88), ('Expansion of Market Reach', 75), ('Financial Health and Deal Structure', 75), ('Investor Confidence', 73), ('Strategic Expansion', 70), ('Investor Perception', 67), ('Financial Health Perception', 63), ('Complementary Product Offerings', 57), ('Financial Synergies', 56), ('Cost Synergies', 56), ('Financial Performance', 53), ('Financial Performance Expectations', 50), ('Complementary Technologies', 48)]
# Most common reasons - Non-Value Enhancing Deals: [('Integration Risks', 98), ('Dilution of Shares', 75), ('Financial Strain', 69), ('Premium Payment', 28), ('Market Reaction to Strategic Fit', 27), ('Regulatory Concerns', 23), ('Integration Challenges', 23), ('Financial Impact', 17), ('Regulatory Hurdles', 15), ('Investor Sentiment', 14), ('Market Reaction to Strategy', 11), ('Market Perception and Integration Concerns', 10), ('Operational Disruptions', 10), ('Market Reaction', 9), ('Market Perception and Strategic Fit', 8), ('Industry Misalignment', 8), ('Market Reaction to Uncertainty', 8), ('Financial Health Concerns', 8), ('Market Perception and Integration Risks', 8), ('Debt Load', 8)]

# %% [markdown]
# ## Create a Dataframe of `Reasons`

# %%
# Create a DataFrame for the most common reasons
common_reasons = list(set(list(full_sample_reason_freq.keys()) + list(value_enhancing_reason_freq.keys()) + list(non_value_enhancing_reason_freq.keys())))

data = {
    'Reason': common_reasons,
    'Full Sample': [full_sample_reason_freq.get(reason, 0) for reason in common_reasons],
    'Value Enhancing Deals': [value_enhancing_reason_freq.get(reason, 0) for reason in common_reasons],
    'Non-Value Enhancing Deals': [non_value_enhancing_reason_freq.get(reason, 0) for reason in common_reasons]
}

df_common_reasons = pd.DataFrame(data)
df_common_reasons = df_common_reasons.sort_values(by='Full Sample', ascending=False)

# %%
# Display the DataFrame
df_common_reasons.head()
# Out:
#                          Reason  Full Sample  Value Enhancing Deals  \
# 36                    Synergies          229                    229
# 245           Market Perception          197                    197
# 696               Strategic Fit          183                    183
# 896         Synergy Realization          182                    182
# 867  Expansion into New Markets          130                    130
#
#      Non-Value Enhancing Deals
# 36                           0
# 245                          0
# 696                          0
# 896                          0
# 867                          0

# %% [markdown]
# ## Save the Output

# %%
# Save the DataFrame to an Excel file
output_file_path = '/content/drive/My Drive/RoboAdvisor/07_2024/results/Cleaned/ValueEnhancingReasonsInsample4turbo.xlsx'
df_common_reasons.to_excel(output_file_path, index=False)
